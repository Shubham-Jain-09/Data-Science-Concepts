# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\shubham jain\\AI 7\\Pdata'

# %%
data=pd.read_csv('store.csv',encoding='ANSI',sep=',',header=0)

# %%
data.head(9)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 5       6  CA-2011-115812    6/9/2011   6/14/2011  Standard Class    BH-11710
# 6       7  CA-2011-115812    6/9/2011   6/14/2011  Standard Class    BH-11710
# 7       8  CA-2011-115812    6/9/2011   6/14/2011  Standard Class    BH-11710
# 8       9  CA-2011-115812    6/9/2011   6/14/2011  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# ...

# %%
# Method By which can know about encoding of file
with open('store.csv')as f:
    print(f)
# Out:
# <_io.TextIOWrapper name='store.csv' mode='r' encoding='cp1252'>

# %%
data.columns.tolist()
# Out:
# ['Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
data.shape
# Out:
# (9994, 21)

# %% [markdown]
# # Data Manipulation Task
# - Filtering Data
# - Selecting columns
# - Sorting data
# - Adding New Column
# - Deleting A Column
# - GroupBy Aggregation
# - Handling Dates

# %%
data.City.unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
data.Country.nunique()
# Out:
# 1

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null object
# Ship Date        9994 non-null object
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# dtypes: float64(3), int64(3), object(15)
# ...

# %%
data[data.Region=='East']['Quantity']
# Out:
# 23       2
# 27       7
# 28       2
# 29       3
# 30       2
#         ..
# 9968     2
# 9969     7
# 9981     5
# 9984    10
# 9985     4
# Name: Quantity, Length: 2848, dtype: int64

# %%
data.query("Region=='East'").head()
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 23      24  US-2014-156909  7/17/2014  7/19/2014    Second Class    SF-20065
# 27      28  US-2012-150630  9/17/2012  9/21/2012  Standard Class    TB-21520
# 28      29  US-2012-150630  9/17/2012  9/21/2012  Standard Class    TB-21520
# 29      30  US-2012-150630  9/17/2012  9/21/2012  Standard Class    TB-21520
# 30      31  US-2012-150630  9/17/2012  9/21/2012  Standard Class    TB-21520
#
#       Customer Name   Segment        Country          City  ... Postal Code  \
# 23  Sandra Flanagan  Consumer  United States  Philadelphia  ...       19140
# 27  Tracy Blumstein  Consumer  United States  Philadelphia  ...       19140
# 28  Tracy Blumstein  Consumer  United States  Philadelphia  ...       19140
# 29  Tracy Blumstein  Consumer  United States  Philadelphia  ...       19140
# 30  Tracy Blumstein  Consumer  United States  Philadelphia  ...       19140
#
# ...

# %%
data.query("Region=='East'")['Quantity'].sum()
# Out:
# 10618

# %%
data.query("Region=='East'").sort_values('Sales',ascending=False)['Customer ID'].head(10)
# Out:
# 2623    TA-21385
# 4190    HL-15040
# 4277    BS-11365
# 6425    CC-12370
# 6626    TB-21400
# 7666    DR-12940
# 6340    TS-21370
# 1085    KD-16270
# 1803    JA-15970
# 8204    KD-16495
# Name: Customer ID, dtype: object

# %%
data.query("Region=='East'").sort_values('Discount',ascending=False)['Customer ID'].head(10)
# Out:
# 4823    CK-12205
# 8536    HD-14785
# 4711    JO-15280
# 4756    EB-13870
# 8886    BS-11590
# 8526    SP-20920
# 1066    TS-21160
# 8352    BO-11350
# 2133    WB-21850
# 9344    CK-12325
# Name: Customer ID, dtype: object

# %%
data.groupby('Region',as_index=False).agg({'Quantity':'mean'})
# Out:
#     Region  Quantity
# 0  Central  3.779595
# 1     East  3.728230
# 2    South  3.832716
# 3     West  3.829535

# %%
data.query("Region=='South'")['Sales'].sum()
# Out:
# 391721.905

# %%
data[data['Region']=='South']['Sales'].sum()
# Out:
# 391721.905

# %%
data.groupby('Segment',as_index=False)['Discount'].mean()
# Out:
#        Segment  Discount
# 0     Consumer  0.158141
# 1    Corporate  0.158228
# 2  Home Office  0.147128

# %%
data.query("Segment=='Consumer'" and "Region=='South'")
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 12        13  CA-2014-114412   4/16/2014   4/21/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9971    9972  CA-2012-103772   6/28/2012    7/2/2012  Standard Class
# 9980    9981  US-2012-151435    9/6/2012    9/9/2012    Second Class
# 9987    9988  CA-2014-163629  11/18/2014  11/22/2014  Standard Class
# 9988    9989  CA-2014-163629  11/18/2014  11/22/2014  Standard Class
# 9989    9990  CA-2011-110422   1/22/2011   1/24/2011    Second Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %%
data[(data['Segment']=='Consumer') & (data['Region']=='South')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 1          2  CA-2013-152156   11/9/2013  11/12/2013    Second Class
# 3          4  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 4          5  US-2012-108966  10/11/2012  10/18/2012  Standard Class
# 12        13  CA-2014-114412   4/16/2014   4/21/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9856    9857  CA-2011-120950   11/6/2011  11/11/2011  Standard Class
# 9881    9882  CA-2011-153927   8/12/2011   8/13/2011     First Class
# 9882    9883  CA-2011-153927   8/12/2011   8/13/2011     First Class
# 9980    9981  US-2012-151435    9/6/2012    9/9/2012    Second Class
# 9989    9990  CA-2011-110422   1/22/2011   1/24/2011    Second Class
#
#      Customer ID       Customer Name   Segment        Country  \
# 0       CG-12520         Claire Gute  Consumer  United States
# ...

# %%
data[(data['Segment']=='Consumer')& (data['Region']=='South') & (data['Customer ID']=='CG-12520')]
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
# 1       2  CA-2013-152156  11/9/2013  11/12/2013  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
data.groupby('Region',as_index=False)['Discount'].mean().rename(columns={'Discount':'Avg. Discount'})
# Out:
#     Region  Avg. Discount
# 0  Central       0.240353
# 1     East       0.145365
# 2    South       0.147253
# 3     West       0.109335

# %%
data.Region.unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
data.groupby('Region',as_index=False)['Discount'].mean().sort_values('Discount')
# Out:
#     Region  Discount
# 3     West  0.109335
# 1     East  0.145365
# 2    South  0.147253
# 0  Central  0.240353

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
# Row ID           9994 non-null int64
# Order ID         9994 non-null object
# Order Date       9994 non-null object
# Ship Date        9994 non-null object
# Ship Mode        9994 non-null object
# Customer ID      9994 non-null object
# Customer Name    9994 non-null object
# Segment          9994 non-null object
# Country          9994 non-null object
# City             9994 non-null object
# State            9994 non-null object
# Postal Code      9994 non-null int64
# Region           9994 non-null object
# Product ID       9994 non-null object
# Category         9994 non-null object
# Sub-Category     9994 non-null object
# Product Name     9994 non-null object
# Sales            9994 non-null float64
# Quantity         9994 non-null int64
# Discount         9994 non-null float64
# Profit           9994 non-null float64
# dtypes: float64(3), int64(3), object(15)
# ...

# %%
data.groupby('Segment',as_index=False)['Profit'].max().sort_values('Profit',ascending=False)
# Out:
#        Segment     Profit
# 1    Corporate  8399.9760
# 0     Consumer  6719.9808
# 2  Home Office  3919.9888

# %%
data.groupby('Category',as_index=False)['Profit'].max().sort_values('Profit',ascending=False)
# Out:
#           Category    Profit
# 2       Technology  8399.976
# 1  Office Supplies  4946.370
# 0        Furniture  1013.127

# %%
data.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data.Sales.head()
# Out:
# 0    261.9600
# 1    731.9400
# 2     14.6200
# 3    957.5775
# 4     22.3680
# Name: Sales, dtype: float64

# %%
data['Avg_Sales']=(data.Sales/data.Sales.mean())

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 1       2  CA-2013-152156   11/9/2013  11/12/2013    Second Class    CG-12520
# 2       3  CA-2013-138688   6/13/2013   6/17/2013    Second Class    DV-13045
# 3       4  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
# 4       5  US-2012-108966  10/11/2012  10/18/2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data.groupby('Category')[['Sales','Profit']].agg(['mean',max])
# Out:
#                       Sales                Profit
#                        mean        max       mean       max
# Category
# Furniture        349.834887   4416.174   8.699327  1013.127
# Office Supplies  119.324101   9892.740  20.327050  4946.370
# Technology       452.709276  22638.480  78.752002  8399.976

# %%
def get_sum(x):
    return sum(x)
data[['Sales','Discount','Profit','Quantity']].apply(get_sum,axis=0)
# Out:
# Sales       2.297201e+06
# Discount    1.561090e+03
# Profit      2.863970e+05
# Quantity    3.787300e+04
# dtype: float64

# %%
(data['Profit']>5000).sum()
# Out:
# 3

# %%
pro_flag=(data['Profit']>5000).map({True:'Above 5000',False:'Below 5000'})

# %%
data.columns.tolist()

# %%
data['Order Date']=pd.to_datetime(data['Order Date'])
data['Ship Date']=pd.to_datetime(data['Ship Date'])

# %%
data['Duration']=data['Ship Date']-data['Order Date']

# %%
data.Duration.dtype

# %%
data.info()

# %%
data[(data.Duration>'5 days')].groupby('Category')['Category'].size()

# %%
((data.Duration>'5 days').sum()/data.Duration.shape[0])*100
