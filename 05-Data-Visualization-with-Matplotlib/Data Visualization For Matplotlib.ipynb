# %% [markdown]
# ## Topics
# ### uni_variate plots
# - Histogram
# - Density Plot
# - Box Plot
# - Bar Charts
# - Line Charts
# - Pie Chart
# - violin plot
# - count plot
# #### Libraries used will be
# - pandas
# - matplotlib
# - seaborn
#
# #### Also we will see some bi_variate plots
# - Scatter plot
# - Heatmap
# - pairplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings 
import seaborn as sns
from mpl_toolkits.mplot3d.axes3d import Axes3D
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('hrdata.csv')
data2=pd.read_csv('MMix.csv')
data3=pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
data3.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Uni-Variate Plots
# #### 1 Histogram

# %%
plt.hist(data.Income)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.hist(data.Income,bins=10,color='blue',alpha=0.7,orientation='horizontal');

# %%
plt.figure(figsize=(15,7))
plt.hist(data.Income,bins=10,color='blue',alpha=0.7);
plt.xlabel('Income')
plt.ylabel('Frequency of no. of employees')
plt.title('Histogram Income Plot Demo')
plt.savefig('Histogram_plot.jpg')

# %%
from matplotlib import style

# %%
#style.use( 'seaborn')
plt.hist(data.Income,bins=10,color='blue',alpha=0.7);

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
his=data.Income.plot(kind='hist',ylim=400)

# %% [markdown]
# #### 2 Density Plot

# %%
data.Income.plot(kind='density',ls='--')

# %%
plt.figure(figsize=(15,9))
data.Income.plot(kind='density',ls='--',secondary_y=True);
plt.xlabel('Income')
plt.ylabel('Frequency of no. of employees')
plt.title('Density Income Plot Demo')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hist with density

# %%
plt.figure(figsize=(15,9))
ax=data.Income.plot(kind='hist',color='white',ylim=400)
ax2=data.Income.plot(kind='density',color='blue',ls='--',secondary_y=True)
ax.set_ylabel('No. of emp')
ax2.set_ylabel('Density')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Line chart

# %%
data2.head()
# Out:
#    NewVolSales  Base Price  Radio     TV   InStore  Facebook  Twitter  \
# 0        19564   15.029276   245.0  145.4   15.452         0        0
# 1        19387   15.029276   314.0   66.0   16.388         0        0
# 2        23889   14.585093   324.0  155.1   62.692         0        0
# 3        20055   15.332887   298.0  114.5   16.573         0        0
# 4        20064   15.642632   279.0   96.5   41.504         0        0
#
#    WebCamp  Online Website Campaign   ...      tvst60      tvst70      tvst80  \
# 0        0       0               NaN  ...   87.240000  101.780000  116.320000
# 1        0       0               NaN  ...   74.496000   76.734000   76.064000
# 2        0       0               NaN  ...  122.858400  131.590200  139.292800
# 3        0       0               NaN  ...  117.843360  119.627060  119.458560
# 4        0       0               NaN  ...  105.037344  103.438118  101.091712
#
# ...

# %%
plt.plot(data2['NewVolSales'])
plt.xlabel('week')
plt.ylabel('volume sales in thousands')
plt.title('volume sales')
# Out:
# Text(0.5, 1.0, 'volume sales')

# %%
plt.plot(data2['NewVolSales'],ls='--',marker='s',ms=6,c='M')
plt.xlabel('week')
plt.ylabel('volume sales in thousands')
plt.title('volume sales')
# Out:
# Text(0.5, 1.0, 'volume sales')

# %% [markdown]
# # Box plot

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
plt.figure(figsize=(15,9))
plt.boxplot(data['Income'],vert=False)
plt.tight_layout()

# %%
ax = sns.boxplot(data = data3,orient='h',palette='Set3')

# %% [markdown]
# # Count plot

# %%
sns.countplot(data['Gender'])

# %% [markdown]
# # Bi-variate

# %% [markdown]
# # scatter plot

# %%
plt.figure(figsize=(15,9))
plt.scatter(x=data['Age'],
           y=data['Income'],color='magenta',alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Gender')
plt.title('Age,Income')
# Out:
# Text(0.5, 1.0, 'Age,Income')

# %% [markdown]
# # Pair Plot

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
sns.pairplot(data3,hue='Species')

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x=data['Gender'],y=data['Income'])

# %% [markdown]
# ## pie plot

# %%
plt.figsize=(15,9)
x=[88,89,88,92,70]
sub=['Physics','Chemistry','Math','English','PE']
colors=['red','g','b','M','yellow']
plt.pie(x,labels=sub,explode=(0.4,0,0,0,0),colors=colors);

# %% [markdown]
# ## Heat Map

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  ...  \
# 0       Yes  Female   41        Single        College  Life Sciences  ...
# 1        No    Male   49       Married  Below College  Life Sciences  ...
# 2       Yes    Male   37        Single        College          Other  ...
# 3        No  Female   33       Married         Master  Life Sciences  ...
# 4        No    Male   27       Married  Below College        Medical  ...
#
# ...

# %%
plt.figsize=(15,9)
sns.heatmap(data3.corr(),annot=True,cmap='magma')

# %% [markdown]
# ## Displaying images

# %%
img=plt.imread('most-expensive-cars-lead.jpg')

# %%
img.shape

# %%
plt.imshow(img)
# plt.xticks([])
# plt.yticks([])
plt.axis('off');
